# %% [markdown]
# <a href="https://colab.research.google.com/github/devJuanMiarelli/Naive-Bayes-Analise-de-sentimento/blob/main/NaiveBayes_an%C3%A1liseDeSentimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Lista de palavras positivas
palavras_positivas = [
    "ótimo", "maravilhoso", "incrível", "fantástico", "adorável", "excelente", "bom", "grande", "brilhante",
    "espetacular", "fenomenal", "extraordinário", "esplêndido", "magnífico", "fabuloso", "sensacional",
    "estupendo", "perfeito", "maravilha", "notável", "apreciado", "encantador", "hilariante", "alegre",
    "divertido", "delicioso", "saboroso", "apetitoso", "excepcional", "sublime", "radiante", "radioso",
    "vibrante", "otimista", "empolgante", "energizante", "inspirador", "motivador", "revigorante",
    "reconfortante", "edificante", "consolador", "gratificante", "satisfatório", "celestial", "triunfante",
    "triunfo", "fascinante", "incomparável", "prestigioso", "glorioso", "exultante", "júbilo", "entusiasmo",
    "entusiasta", "apaixonante", "cativante", "envolvente", "envolvente", "arrebatador", "encorajador",
    "estimulante", "aplaudido", "aplaudível", "admirável", "respeitável", "honroso", "gentil", "bondoso",
    "amável", "amoroso", "carinhoso", "afetuoso", "generoso", "solidário", "altruísta", "compassivo",
    "atencioso", "tolerante", "paciente", "perseverante", "resiliente", "otimista", "confiante", "seguro",
    "sereno", "calmo", "pacífico", "tranquilo", "harmonioso", "pacificador", "conciliador", "compaixão",
    "compreensivo", "compreensão", "consideração", "respeito", "gratidão", "reconhecimento", "estima",
    "amizade", "companheirismo", "solidariedade", "união", "colaboração", "cooperação", "apoio", "encorajamento"
]

# Gerar 100 frases positivas aleatórias
frases_positivas = [" ".join(random.sample(palavras_positivas, random.randint(3, 8))) for _ in range(100)]

# Imprimir as frases positivas
for frase in frases_positivas:
    print('"' + frase + '",')
# Out:
# "companheirismo harmonioso carinhoso solidário fabuloso gentil",
# "amoroso carinhoso extraordinário compaixão respeito",
# "glorioso brilhante radioso ótimo revigorante",
# "otimista compreensão glorioso consideração admirável bom",
# "estupendo incomparável encantador aplaudido admirável",
# "arrebatador respeito afetuoso aplaudido maravilhoso pacífico compreensivo perseverante",
# "sublime reconfortante estima otimista",
# "compreensão harmonioso aplaudível extraordinário radiante solidariedade notável magnífico",
# "solidariedade apoio resiliente",
# "amável glorioso gratificante",
# "aplaudido amoroso incomparável conciliador atencioso altruísta",
# "pacificador divertido compassivo harmonioso consolador fabuloso maravilhoso estima",
# "sereno divertido celestial incrível apreciado harmonioso fenomenal otimista",
# "perfeito admirável incomparável conciliador maravilhoso energizante",
# "carinhoso inspirador excepcional grande tolerante",
# ...

# %%
import random

# Lista de palavras negativas
palavras_negativas = [
    "terrível", "horrível", "ruim", "péssimo", "desagradável", "detestável", "desastroso",
    "desanimador", "deprimente", "desalentador", "triste", "decepcionante", "desalentador",
    "desagradável", "chato", "repugnante", "miserável", "nojento", "asqueroso", "abominável",
    "aborrecido", "entediante", "aborrecido", "desconfortável", "inaceitável", "desesperador",
    "insatisfatório", "frustrante", "desastroso", "nefasto", "catastrófico", "irritante",
    "indesejável", "desfavorável", "incômodo", "inaceitável", "opressivo", "odioso", "inaceitável",
    "inaceitável", "repelente", "aterrorizante", "infernal", "irritante", "incomodativo",
    "enfadonho", "abafado", "desesperador", "lamentável", "desinteressante", "insuportável",
    "horrível", "horrendo", "mísero", "pavoroso", "terrífico", "assustador", "trágico",
    "angustiante", "assombroso", "doloroso", "assustador", "medonho", "apavorante", "infeliz",
    "vexatório", "vexante", "vergonhoso", "embaraçoso", "desmoralizante", "desalentador",
    "desanimador", "desapontante", "derrotista", "cínico", "triste", "abatido", "desconsolado",
    "melancólico", "deprimido", "desesperado", "solitário", "isolado", "cabisbaixo", "entristecido",
    "miserável", "desgraçado", "mal-humorado", "aborrecido"
]

# Gerar 100 frases negativas aleatórias
frases_negativas = [" ".join(random.sample(palavras_negativas, random.randint(3, 8))) for _ in range(100)]

# Imprimir as frases positivas
for frase in frases_negativas:
    print('"' + frase + '",')
# Out:
# "deprimido incomodativo insatisfatório triste doloroso entristecido",
# "odioso incomodativo vexatório desalentador catastrófico deprimente desalentador",
# "aborrecido apavorante isolado",
# "inaceitável miserável desesperado ruim desagradável infeliz",
# "aborrecido derrotista cabisbaixo trágico desesperado",
# "miserável apavorante cabisbaixo nojento irritante indesejável cínico",
# "inaceitável desesperador mal-humorado horrível desagradável",
# "lamentável aterrorizante mísero frustrante irritante",
# "solitário inaceitável entediante trágico desastroso",
# "aborrecido horrível asqueroso",
# "embaraçoso irritante repelente",
# "desastroso asqueroso angustiante ruim embaraçoso",
# "assustador trágico desapontante terrível desmoralizante desesperado nefasto",
# "irritante cínico ruim abafado angustiante mísero entediante assombroso",
# "opressivo desesperador desconsolado vexante assustador",
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Dados de treinamento
documentos_treinamento = [
  "companheirismo harmonioso carinhoso solidário fabuloso gentil",
  "amoroso carinhoso extraordinário compaixão respeito",
  "glorioso brilhante radioso ótimo revigorante",
  "otimista compreensão glorioso consideração admirável bom",
  "estupendo incomparável encantador aplaudido admirável",
  "arrebatador respeito afetuoso aplaudido maravilhoso pacífico compreensivo perseverante",
  "sublime reconfortante estima otimista",
  "compreensão harmonioso aplaudível extraordinário radiante solidariedade notável magnífico",
  "solidariedade apoio resiliente",
  "amável glorioso gratificante",
  "aplaudido amoroso incomparável conciliador atencioso altruísta",
  "pacificador divertido compassivo harmonioso consolador fabuloso maravilhoso estima",
  "sereno divertido celestial incrível apreciado harmonioso fenomenal otimista",
  "perfeito admirável incomparável conciliador maravilhoso energizante",
  "carinhoso inspirador excepcional grande tolerante",
  "paciente harmonioso encantador inspirador júbilo fabuloso envolvente arrebatador",
  "pacífico ótimo tranquilo incomparável maravilhoso sublime entusiasta",
  "brilhante reconhecimento arrebatador encorajador esplêndido apoio fascinante",
  "fascinante apoio reconfortante esplêndido notável amizade colaboração",
  "calmo admirável sensacional",
  "fenomenal perseverante solidariedade consolador revigorante estimulante",
  "sublime celestial calmo",
  "espetacular estima compaixão edificante excelente alegre exultante seguro",
  "altruísta companheirismo estupendo esplêndido compaixão respeitável incomparável",
  "excelente maravilhoso amável",
  "extraordinário sereno altruísta",
  "carinhoso entusiasta colaboração ótimo sensacional entusiasmo maravilha tranquilo",
  "ótimo vibrante cooperação glorioso",
  "satisfatório gratidão triunfo divertido",
  "apetitoso pacífico paciente",
  "edificante celestial pacificador radioso",
  "hilariante solidariedade sensacional generoso fascinante maravilha delicioso",
  "ótimo compassivo espetacular",
  "fabuloso sublime empolgante estimulante incrível exultante companheirismo",
  "exultante sublime compassivo",
  "carinhoso respeito edificante atencioso incrível",
  "companheirismo amizade aplaudível",
  "atencioso alegre cativante",
  "inspirador exultante amável empolgante entusiasta delicioso edificante envolvente",
  "envolvente radioso estupendo admirável atencioso",
  "envolvente admirável aplaudível cooperação glorioso apaixonante",
  "vibrante edificante prestigioso solidariedade cooperação",
  "união amizade tolerante radioso radiante aplaudido tranquilo",
  "consideração fenomenal tranquilo celestial generoso saboroso perseverante ótimo",
  "hilariante edificante solidariedade",
  "fantástico apoio satisfatório entusiasmo alegre prestigioso altruísta",
  "compassivo radiante respeitável otimista cooperação",
  "aplaudível gratidão apreciado",
  "colaboração apetitoso respeito ótimo esplêndido excelente encorajador",
  "glorioso tranquilo consideração respeitável compreensão",
  "encantador envolvente entusiasta solidário apaixonante harmonioso gratidão",
  "amizade triunfante prestigioso triunfo revigorante atencioso",
  "bondoso empolgante fascinante júbilo resiliente sensacional calmo",
  "extraordinário esplêndido compaixão",
  "atencioso resiliente delicioso edificante bom amizade",
  "excelente colaboração carinhoso honroso vibrante",
  "maravilhoso entusiasmo apetitoso entusiasta",
  "excelente ótimo fascinante exultante sereno encorajamento revigorante",
  "gratificante radioso respeitável admirável satisfatório amizade celestial",
  "sublime consideração compaixão seguro paciente confiante espetacular atencioso",
  "encantador otimista hilariante vibrante gratidão extraordinário revigorante",
  "respeitável exultante harmonioso",
  "inspirador reconfortante incomparável cooperação honroso",
  "otimista confiante celestial aplaudido bondoso compreensão entusiasta espetacular",
  "satisfatório admirável arrebatador glorioso",
  "aplaudível bondoso tolerante calmo glorioso grande perseverante",
  "compreensão maravilhoso otimista amoroso delicioso",
  "excelente bondoso estupendo amoroso grande adorável",
  "tranquilo harmonioso entusiasta",
  "respeito compaixão maravilha aplaudível sublime conciliador envolvente fenomenal",
  "perfeito consideração bom compreensão altruísta seguro união fenomenal",
  "arrebatador solidariedade brilhante apreciado encorajamento colaboração otimista radiante",
  "confiante hilariante maravilha generoso radiante divertido reconhecimento espetacular",
  "incomparável altruísta envolvente",
  "colaboração delicioso tolerante ótimo cooperação apetitoso otimista",
  "revigorante brilhante calmo satisfatório cativante estima perfeito",
  "extraordinário amoroso amizade triunfante seguro empolgante alegre",
  "hilariante pacífico maravilha",
  "júbilo amizade maravilhoso bondoso fascinante radiante maravilha",
  "consideração revigorante calmo apaixonante",
  "apetitoso apaixonante notável",
  "compaixão estupendo hilariante encorajamento atencioso",
  "ótimo aplaudível perseverante sereno seguro altruísta envolvente",
  "encorajamento pacífico motivador entusiasta radiante solidariedade maravilhoso união",
  "triunfo cativante cooperação reconfortante glorioso magnífico envolvente esplêndido",
  "gentil paciente envolvente divertido pacificador encorajador",
  "entusiasmo seguro amoroso apoio excelente",
  "compreensão triunfante união seguro motivador pacífico extraordinário compassivo",
  "tolerante seguro estimulante união carinhoso",
  "conciliador alegre compreensivo",
  "gratidão energizante consolador respeito glorioso",
  "glorioso entusiasmo otimista maravilha cativante encorajamento",
  "alegre envolvente gratidão carinhoso sensacional apreciado edificante radioso",
  "estimulante celestial encantador sensacional entusiasmo triunfo aplaudido encorajamento",
  "incrível solidariedade revigorante resiliente seguro delicioso consideração",
  "bom perfeito envolvente amável cativante encantador",
  "gratificante compaixão cooperação maravilha tranquilo carinhoso otimista conciliador",
  "colaboração espetacular delicioso júbilo",
  "compreensivo fantástico inspirador saboroso apoio notável",
  "resiliente companheirismo inspirador ótimo encorajador colaboração reconfortante", # Exemplo positivo
  "deprimido incomodativo insatisfatório triste doloroso entristecido",
  "odioso incomodativo vexatório desalentador catastrófico deprimente desalentador",
  "aborrecido apavorante isolado",
  "inaceitável miserável desesperado ruim desagradável infeliz",
  "aborrecido derrotista cabisbaixo trágico desesperado",
  "miserável apavorante cabisbaixo nojento irritante indesejável cínico",
  "inaceitável desesperador mal-humorado horrível desagradável",
  "lamentável aterrorizante mísero frustrante irritante",
  "solitário inaceitável entediante trágico desastroso",
  "aborrecido horrível asqueroso",
  "embaraçoso irritante repelente",
  "desastroso asqueroso angustiante ruim embaraçoso",
  "assustador trágico desapontante terrível desmoralizante desesperado nefasto",
  "irritante cínico ruim abafado angustiante mísero entediante assombroso",
  "opressivo desesperador desconsolado vexante assustador",
  "terrível embaraçoso mísero incômodo aterrorizante desagradável deprimido desanimador",
  "aborrecido abafado horrível",
  "aborrecido desesperador horrível cabisbaixo desalentador",
  "inaceitável decepcionante vergonhoso desagradável",
  "horrendo desfavorável aborrecido abominável nefasto mal-humorado",
  "desinteressante opressivo desesperador inaceitável lamentável embaraçoso",
  "desconsolado inaceitável infernal isolado desastroso",
  "indesejável miserável desesperador detestável desanimador",
  "desconfortável indesejável infeliz repelente melancólico frustrante",
  "vergonhoso aborrecido miserável",
  "desconsolado irritante desanimador opressivo desgraçado asqueroso",
  "nefasto desgraçado miserável enfadonho odioso desesperador desalentador",
  "infeliz frustrante desfavorável doloroso pavoroso inaceitável desesperado",
  "nefasto mísero desapontante abatido desconsolado",
  "desapontante abatido aborrecido ruim insatisfatório desalentador nojento",
  "triste desagradável inaceitável nojento insuportável",
  "miserável insatisfatório inaceitável",
  "lamentável deprimente mísero infernal abominável",
  "frustrante incomodativo desgraçado desalentador decepcionante medonho inaceitável nojento",
  "medonho desinteressante trágico abatido vergonhoso",
  "opressivo trágico desanimador isolado doloroso desastroso",
  "inaceitável mal-humorado desanimador cabisbaixo desesperado vexante",
  "desapontante horrível isolado vexatório solitário",
  "inaceitável aterrorizante cabisbaixo infernal deprimente",
  "triste miserável vexante desfavorável nefasto péssimo",
  "indesejável medonho desastroso horrendo melancólico triste terrível",
  "repugnante triste catastrófico terrível desastroso incômodo vexatório",
  "apavorante indesejável vexatório doloroso infernal inaceitável irritante aborrecido",
  "apavorante incomodativo desesperado",
  "triste assustador cínico insatisfatório desalentador",
  "pavoroso irritante horrível decepcionante doloroso",
  "cínico doloroso chato desanimador assustador repelente triste horrendo",
  "péssimo repelente miserável assustador irritante aterrorizante insatisfatório",
  "opressivo irritante inaceitável triste odioso vexatório embaraçoso desastroso",
  "desanimador assustador angustiante desalentador desconsolado desgraçado",
  "abafado catastrófico asqueroso desalentador miserável terrível desagradável terrífico",
  "desalentador opressivo horrendo derrotista",
  "inaceitável desconfortável melancólico irritante lamentável",
  "abominável desanimador desanimador",
  "apavorante assustador derrotista aborrecido odioso péssimo",
  "inaceitável horrível terrível desmoralizante",
  "frustrante apavorante desesperador assustador desagradável péssimo incomodativo deprimido",
  "infernal lamentável nojento",
  "nefasto mal-humorado desconfortável desastroso desmoralizante triste péssimo triste",
  "nefasto triste aterrorizante abafado cabisbaixo",
  "inaceitável triste vergonhoso repelente odioso terrífico desfavorável",
  "incomodativo deprimente desgraçado",
  "horrendo desagradável desanimador miserável terrífico deprimente",
  "triste incômodo aborrecido desfavorável assustador desalentador entediante detestável",
  "incômodo inaceitável desinteressante ruim triste opressivo desagradável desastroso",
  "mal-humorado infernal repelente",
  "horrível miserável aborrecido nefasto melancólico vergonhoso terrífico",
  "desfavorável inaceitável angustiante",
  "vexante deprimido mísero apavorante desfavorável desalentador",
  "entristecido triste desconfortável",
  "isolado entristecido desalentador apavorante assustador insuportável desesperador",
  "embaraçoso entediante vergonhoso indesejável desanimador derrotista inaceitável enfadonho",
  "apavorante nojento infeliz chato horrível odioso desconsolado repugnante",
  "deprimido desapontante aterrorizante",
  "vergonhoso angustiante opressivo triste",
  "decepcionante desmoralizante repelente desinteressante desastroso desastroso",
  "desesperador abominável deprimente desalentador irritante",
  "pavoroso cabisbaixo deprimente solitário péssimo melancólico entediante assustador",
  "aborrecido terrífico desastroso detestável",
  "enfadonho aborrecido decepcionante assustador incômodo",
  "incomodativo horrendo nojento irritante péssimo",
  "irritante desapontante pavoroso doloroso desagradável irritante abatido repugnante",
  "desanimador cabisbaixo desconsolado",
  "infeliz trágico chato",
  "insuportável inaceitável doloroso incomodativo",
  "odioso pavoroso triste",
  "odioso desalentador miserável angustiante infernal",
  "vergonhoso cínico derrotista",
  "miserável terrível vergonhoso assustador desmoralizante infeliz abatido",
  "desgraçado abafado inaceitável doloroso entristecido aborrecido desapontante melancólico",
  "inaceitável vergonhoso vexante angustiante abafado",
  "inaceitável desesperado irritante opressivo infeliz desastroso incômodo odioso",
  "embaraçoso abominável entediante cínico assustador infernal",
  "terrível miserável desmoralizante",
  "desesperador aborrecido desalentador pavoroso aborrecido melancólico",
  "vergonhoso desastroso mísero",
  "chato repelente desgraçado desalentador aborrecido cabisbaixo catastrófico",
  "vexatório desalentador aterrorizante aborrecido frustrante entristecido assustador",
  "doloroso cabisbaixo desanimador mal-humorado detestável aborrecido desfavorável ruim",
  "aborrecido desalentador irritante péssimo desalentador desesperador" #exemplo negativo
]
rotulos_treinamento = ["positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo","positivo","positivo","positivo","positivo",
                       "positivo","positivo","positivo","positivo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo","negativo","negativo","negativo","negativo",
                       "negativo","negativo","negativo","negativo"]

# Vetorizador de palavras
vectorizer = CountVectorizer()

# Vetorizar os dados de treinamento
treinamento = vectorizer.fit_transform(documentos_treinamento)

# Treinar o classificador Naive Bayes
classifier_1 = MultinomialNB()
classifier_2 = MultinomialNB()
classifier_3 = MultinomialNB()

classifier_1.fit(treinamento, rotulos_treinamento)
classifier_2.fit(treinamento, rotulos_treinamento)
classifier_3.fit(treinamento, rotulos_treinamento)

# Exemplo de frase de teste
frase_teste_1 = ["mulher admirável"]
frase_teste_2 = ["menino chato"]
frase_teste_3 = ["homem desrespeitoso"]

# Vetorizar a frase de teste
X_frase_teste = vectorizer.transform(frase_teste_1)
Y_frase_teste = vectorizer.transform(frase_teste_2)
Z_frase_teste = vectorizer.transform(frase_teste_3)

# Fazer previsões na frase de teste
previsao1 = classifier_1.predict(X_frase_teste)
previsao2 = classifier_2.predict(Y_frase_teste)
previsao3 = classifier_3.predict(Z_frase_teste)

# Imprimir a previsão
print("Previsão para a frase X:", previsao1)
print("\n")
print("Previsão para a frase Y:", previsao2)
print("\n")
print("Previsão para a frase Z:", previsao3)
print("\n")
# Out:
# Previsão para a frase X: ['positivo']
#
#
# Previsão para a frase Y: ['negativo']
#
#
# Previsão para a frase Z: ['negativo']
